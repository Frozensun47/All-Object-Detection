# %%
import io
import base64
from PIL import Image
import matplotlib.pyplot as plt

# Read the image from file
buffer = plt.imread('data/temp.jpg')
buffer
# Encode the image to base64 without decoding it to UTF-8
face_base64 = base64.b64encode(buffer).decode()
decoded = base64.b64decode(face_base64)

bytes = Image.open(io.BytesIO(face_base64))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 13
#      10 face_base64 = base64.b64encode(buffer).decode()
#      11 decoded = base64.b64decode(face_base64)
# ---> 13 bytes = Image.open(io.BytesIO(face_base64))
#
# TypeError: a bytes-like object is required, not 'str'

# %%
import io
import base64
from PIL import Image
import matplotlib.pyplot as plt

# Read the image from file
img = plt.imread('data/temp.jpg')
image = Image.fromarray(img)
# Encode the image to base64 without decoding it to UTF-8
buffer = io.BytesIO()
image.save(buffer, format="JPEG")  # You can change the format if your image is in a different format
img_str = base64.b64encode(buffer.getvalue()).decode()

# Decode the base64 string to bytes
decoded = base64.b64decode(img_str)

# Create an Image object from the decoded bytes
img_object = Image.open(io.BytesIO(decoded))

# Display the image using Matplotlib
plt.imshow(img_object)
plt.show()

# %%
bytes

# %%
img = Image.open('data/temp.jpg')

# %%
import numpy as np

# %%
np.array(img)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
# ...

# %%
import requests

url = "https://detect-everything.streamlit.app/empty_get"

response = requests.get(url)

if response.status_code == 200:
    print("Response:")
    print(response.json())
else:
    print(f"Error: {response.status_code}")
    print(response.text)
# Out:
# Response:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\sagar\miniconda3\envs\streamlit\lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\sagar\miniconda3\envs\streamlit\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
# ...

# %%
response = requests.get(url)

print("Response Content:")
print(response.text)
# Out:
# Response Content:
# ...
